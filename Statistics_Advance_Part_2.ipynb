# %% [markdown]
# # Statistics Advance Part 2

# %% [markdown]
# 1. What is hypothesis testing in statistics?
#
#     Hypothesis testing is a statistical method used to make inferences or decisions about a population based on sample data. It involves testing an assumption (the hypothesis) and determining whether there is enough evidence to reject it.

# %% [markdown]
# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis?
#
#     Null Hypothesis (H₀): The default assumption that there is no effect or no difference.
#
#     Alternative Hypothesis (H₁ or Ha): Contradicts the null hypothesis, suggesting there is an effect or difference.

# %% [markdown]
# 3. What is the significance level in hypothesis testing, and why is it important?
#
#     The significance level (α) is the probability of rejecting the null hypothesis when it is actually true. Common values are 0.05 or 0.01. It helps control the Type I error rate.

# %% [markdown]
# 4. What does a P-value represent in hypothesis testing?
#
#     The P-value indicates the probability of obtaining test results at least as extreme as the observed data, assuming the null hypothesis is true.

# %% [markdown]
# 5. How do you interpret the P-value in hypothesis testing?
#
#     If P-value ≤ α, reject the null hypothesis.
#
#     If P-value > α, fail to reject the null hypothesis.

# %% [markdown]
# 6. What are Type 1 and Type 2 errors in hypothesis testing?
#
#     Type 1 Error (False Positive): Rejecting a true null hypothesis.
#
#     Type 2 Error (False Negative): Failing to reject a false null hypothesis.

# %% [markdown]
# 7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
#
#     One-tailed test: Tests for an effect in one direction.
#
#     Two-tailed test: Tests for effects in both directions.

# %% [markdown]
# 8. What is the Z-test, and when is it used in hypothesis testing?
#
#     A Z-test is used when the population variance is known and the sample size is large (n > 30). It checks if the sample mean significantly differs from the population mean.

# %% [markdown]
# 9. How do you calculate the Z-score, and what does it represent in hypothesis testing?
#
#     Z = (X - μ) / σ
#
#     It measures how many standard deviations a data point is from the mean.

# %% [markdown]
# 10. What is the T-distribution, and when should it be used instead of the normal distribution?
#
#     T-distribution is used when the sample size is small (n < 30) and the population standard deviation is unknown. It accounts for more variability.

# %% [markdown]
# 11. What is the difference between a Z-test and a T-test?
#
#     Z-test: Known population variance, large samples.
#
#     T-test: Unknown population variance, small samples.

# %% [markdown]
# 12. What is the T-test, and how is it used in hypothesis testing?
#
#     A T-test compares sample means to determine if they are significantly different. It’s used when the population variance is unknown.

# %% [markdown]
# 13. What is the relationship between Z-test and T-test in hypothesis testing?
#
#     Both are used to test means, but:
#
#     Z-test is for known standard deviation or large samples.
#
#     T-test adjusts for small samples and unknown variance.

# %% [markdown]
# 14. What is a confidence interval, and how is it used to interpret statistical results?
#
#     A confidence interval gives a range of values that is likely to contain the population parameter. For example, a 95% confidence interval means we are 95% confident the parameter lies in that range.

# %% [markdown]
# 15. What is the margin of error, and how does it affect the confidence interval?
#
#     The margin of error represents the range added and subtracted from the sample statistic to form the confidence interval. A larger margin results in a wider interval.

# %% [markdown]
# 16. How is Bayes' Theorem used in statistics, and what is its significance?
#
#     Bayes’ Theorem updates the probability of a hypothesis based on new evidence. It's essential in probabilistic reasoning and decision-making.

# %% [markdown]
# 17. What is the Chi-square distribution, and when is it used?
#
#     The Chi-square distribution is used in tests of independence and goodness of fit for categorical data.

# %% [markdown]
# 18. What is the Chi-square goodness of fit test, and how is it applied?
#
#     It determines whether observed frequencies differ significantly from expected frequencies in one categorical variable.

# %% [markdown]
# 19. What is the F-distribution, and when is it used in hypothesis testing?
#
#     The F-distribution is used in analysis of variance (ANOVA) and in comparing two variances.

# %% [markdown]
# 20. What is an ANOVA test, and what are its assumptions?
#
#     ANOVA tests whether there are significant differences among group means. Assumptions include:
#
#     Independence
#
#     Normality
#
#     Homogeneity of variances

# %% [markdown]
# 21. What are the different types of ANOVA tests?
#
#     One-way ANOVA: One independent variable
#
#     Two-way ANOVA: Two independent variables
#
#     Repeated measures ANOVA: Same subjects across conditions

# %% [markdown]
# 22. What is the F-test, and how does it relate to hypothesis testing?
#
#     An F-test compares variances to see if they are significantly different. It’s the basis for ANOVA and other variance-related tests.

# %% [markdown]
# # Practical Part 1

# %%
# 1. Write a Python Program to generate a random variable and display its value.

import random

# Generate a random float variable between 0 and 1 (continuous uniform)
random_variable = random.random()

print(f"Generated Random Variable: {random_variable}")
# Out:
# Generated Random Variable: 0.8754904231710268

# %%
# 2. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

import numpy as np
import matplotlib.pyplot as plt

sample_means = []
for _ in range(1000):
    sample = np.random.exponential(scale=2.0, size=30)  # non-normal distribution
    sample_means.append(np.mean(sample))

plt.hist(sample_means, bins=30, density=True, color='skyblue')
plt.title("Central Limit Theorem - Distribution of Sample Means")
plt.xlabel("Sample Mean")
plt.ylabel("Frequency")
plt.show()

# %%
# 3. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).

from scipy.stats import norm

x = np.linspace(-4, 4, 1000)
y = norm.pdf(x)

plt.plot(x, y, label="Standard Normal PDF")
plt.title("Standard Normal Distribution")
plt.xlabel("Z")
plt.ylabel("Density")
plt.grid()
plt.legend()
plt.show()

# %%
# 4. Generate random variables and calculate their corresponding probabilities using the binomial distribution.

from scipy.stats import binom

n, p = 10, 0.5
x = np.arange(0, n + 1)
pmf = binom.pmf(x, n, p)

plt.bar(x, pmf, color='orange')
plt.title("Binomial Distribution PMF (n=10, p=0.5)")
plt.xlabel("Successes")
plt.ylabel("Probability")
plt.show()

# %%
# 5. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.

def z_score(x, mean, std_dev):
    return (x - mean) / std_dev

x = 75
mean = 70
std_dev = 5

z = z_score(x, mean, std_dev)
print(f"Z-score: {z:.2f}")
# Out:
# Z-score: 1.00

# %%
# 6. Implement hypothesis testing using Z-statistics for a sample dataset.

from scipy.stats import norm

sample = np.random.normal(102, 10, 50)
pop_mean = 100
pop_std = 10
n = len(sample)

sample_mean = np.mean(sample)
z = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
p_value = 2 * (1 - norm.cdf(abs(z)))

print(f"Z = {z:.3f}, P = {p_value:.4f}")
# Out:
# Z = 0.838, P = 0.4020

# %%
# 7. Create a confidence interval for a dataset using Python and interpret the result.

from scipy.stats import t

sample = np.random.normal(100, 15, 40)
mean = np.mean(sample)
sem = np.std(sample, ddof=1) / np.sqrt(len(sample))
t_critical = t.ppf(0.975, df=len(sample)-1)
margin = t_critical * sem
ci = (mean - margin, mean + margin)

print(f"95% Confidence Interval: {ci}")
# Out:
# 95% Confidence Interval: (np.float64(94.4157153762644), np.float64(102.85150038913217))

# %%
# 8. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

data = np.random.normal(100, 15, 30)
mean = np.mean(data)
sem = np.std(data, ddof=1) / np.sqrt(len(data))
t_crit = t.ppf(0.975, df=len(data)-1)
ci = (mean - t_crit * sem, mean + t_crit * sem)

print(f"95% CI for Normal Distribution Mean: {ci}")
# Out:
# 95% CI for Normal Distribution Mean: (np.float64(90.16649870236166), np.float64(99.43844449102836))

# %%
# 9. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.

x = np.linspace(70, 130, 100)
pdf = norm.pdf(x, loc=100, scale=10)

plt.plot(x, pdf)
plt.title("PDF of Normal Distribution (μ=100, σ=10)")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %%
# 10. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

from scipy.stats import poisson

x = np.arange(0, 20)
cdf = poisson.cdf(x, mu=5)

plt.step(x, cdf, where='post')
plt.title("CDF of Poisson Distribution (λ=5)")
plt.xlabel("k")
plt.ylabel("Cumulative Probability")
plt.grid()
plt.show()

# %%
# 11. Simulate a random variable using a continuous uniform distribution and calculate its expected value.

data = np.random.uniform(10, 20, 1000)
expected_value = np.mean(data)
print(f"Expected Value: {expected_value:.2f}")
# Out:
# Expected Value: 14.90

# %%
# 12. Write a Python program to compare the standard deviations of two datasets and visualize the difference.

data1 = np.random.normal(50, 5, 100)
data2 = np.random.normal(50, 15, 100)

plt.hist(data1, alpha=0.6, label='SD = 5')
plt.hist(data2, alpha=0.6, label='SD = 15')
plt.title("Standard Deviation Comparison")
plt.legend()
plt.show()

# %%
# 13. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

data = np.random.normal(100, 15, 1000)
range_val = np.ptp(data)
iqr = np.percentile(data, 75) - np.percentile(data, 25)

print(f"Range: {range_val:.2f}, IQR: {iqr:.2f}")
# Out:
# Range: 92.36, IQR: 19.49

# %%
# 14. Implement Z-score normalization on a dataset and visualize its transformation.

from sklearn.preprocessing import StandardScaler

data = np.random.normal(60, 10, 100).reshape(-1, 1)
scaler = StandardScaler()
normalized = scaler.fit_transform(data)

plt.hist(normalized, bins=30, color='green')
plt.title("Z-score Normalized Data")
plt.show()

# %%
# 15. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.

from scipy.stats import skew, kurtosis

data = np.random.normal(0, 1, 1000)
print(f"Skewness: {skew(data):.3f}")
print(f"Kurtosis: {kurtosis(data):.3f}")
# Out:
# Skewness: 0.012
# Kurtosis: -0.065

# %%
# 16. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results.

sample = np.random.normal(105, 10, 30)
pop_mean = 100
pop_std = 10

n = len(sample)
sample_mean = np.mean(sample)
z = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
p = 2 * (1 - norm.cdf(abs(z)))

print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z = {z:.2f}, P-value = {p:.4f}")

if p < 0.05:
    print("Reject null hypothesis — significant difference.")
else:
    print("Fail to reject null hypothesis — no significant difference.")
# Out:
# Sample Mean: 104.71
# Z = 2.58, P-value = 0.0098
# Reject null hypothesis — significant difference.

# %% [markdown]
# # Practical Part 2

# %%
# 1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results.

import numpy as np
from scipy.stats import norm

# ----- Sample data -----
np.random.seed(42)  # For reproducibility
sample = np.random.normal(loc=105, scale=10, size=30)  # Sample data
sample_mean = np.mean(sample)

# ----- Population parameters -----
population_mean = 100
population_std = 10  # Known population standard deviation

# ----- Z-test calculation -----
n = len(sample)
standard_error = population_std / np.sqrt(n)
z_score = (sample_mean - population_mean) / standard_error
p_value = 2 * (1 - norm.cdf(abs(z_score)))  # two-tailed test

# ----- Output results -----
print(f"Sample Mean = {sample_mean:.2f}")
print(f"Z-score = {z_score:.3f}")
print(f"P-value = {p_value:.4f}")

# ----- Interpretation -----
alpha = 0.05
if p_value < alpha:
    print("Result: Reject the null hypothesis (significant difference).")
else:
    print("Result: Fail to reject the null hypothesis (no significant difference).")
# Out:
# Sample Mean = 103.12
# Z-score = 1.708
# P-value = 0.0876
# Result: Fail to reject the null hypothesis (no significant difference).

# %%
# 2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.

import numpy as np
from scipy.stats import norm

data = np.random.normal(loc=100, scale=15, size=50)
sample_mean = np.mean(data)
population_mean = 100
std_dev = 15

z = (sample_mean - population_mean) / (std_dev / np.sqrt(len(data)))
p_value = 2 * (1 - norm.cdf(abs(z)))

print(f"Z-score: {z:.3f}, P-value: {p_value:.4f}")
# Out:
# Z-score: -0.603, P-value: 0.5466

# %%
# 3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean.

def one_sample_z_test(sample, population_mean, population_std):
    n = len(sample)
    sample_mean = np.mean(sample)
    z = (sample_mean - population_mean) / (population_std / np.sqrt(n))
    p_value = 2 * (1 - norm.cdf(abs(z)))
    return z, p_value

sample = np.random.normal(102, 10, 50)
z, p = one_sample_z_test(sample, population_mean=100, population_std=10)
print(f"Z = {z:.3f}, P = {p:.4f}")
# Out:
# Z = 1.571, P = 0.1163

# %%
# 4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot.

import matplotlib.pyplot as plt

z_score = z  # from previous test
alpha = 0.05
z_critical = norm.ppf(1 - alpha/2)

x = np.linspace(-4, 4, 1000)
y = norm.pdf(x)

plt.plot(x, y)
plt.axvline(x=-z_critical, color='red', linestyle='--', label="Critical Region")
plt.axvline(x=z_critical, color='red', linestyle='--')
plt.axvline(x=z_score, color='blue', linestyle='-', label=f"Z = {z_score:.2f}")
plt.fill_between(x, y, where=(x <= -z_critical) | (x >= z_critical), color='red', alpha=0.3)
plt.title("Two-Tailed Z-Test Decision Region")
plt.legend()
plt.show()

# %%
# 5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.

def visualize_type_errors(mu0=100, mu1=105, sigma=15, n=30, alpha=0.05):
    se = sigma / np.sqrt(n)
    x = np.linspace(90, 110, 1000)
    z_critical = norm.ppf(1 - alpha / 2)
    lower = mu0 - z_critical * se
    upper = mu0 + z_critical * se

    plt.plot(x, norm.pdf(x, mu0, se), label="H₀", color='blue')
    plt.plot(x, norm.pdf(x, mu1, se), label="H₁", color='green')
    plt.axvline(lower, color='red', linestyle='--')
    plt.axvline(upper, color='red', linestyle='--')
    plt.fill_between(x, norm.pdf(x, mu0, se), where=(x < lower) | (x > upper), color='red', alpha=0.3, label="Type I Error")
    plt.fill_between(x, norm.pdf(x, mu1, se), where=(x > lower) & (x < upper), color='orange', alpha=0.3, label="Type II Error")
    plt.legend()
    plt.title("Type I and Type II Error Visualization")
    plt.show()

visualize_type_errors()

# %%
# 6. Write a Python program to perform an independent T-test and interpret the results.

from scipy.stats import ttest_rel

before = np.random.normal(100, 5, 30)
after = before + np.random.normal(2, 2, 30)

t_stat, p_val = ttest_rel(before, after)
print(f"Paired T-test: T = {t_stat:.3f}, P = {p_val:.4f}")

plt.plot(before, label="Before")
plt.plot(after, label="After")
plt.title("Paired Sample Values")
plt.legend()
plt.show()
# Out:
# Paired T-test: T = -6.520, P = 0.0000

# %%
# 7. Perform a paired sample T-test using Python and visualize the comparison results.

from scipy.stats import ttest_rel

before = np.random.normal(100, 5, 30)
after = before + np.random.normal(2, 2, 30)

t_stat, p_val = ttest_rel(before, after)
print(f"Paired T-test: T = {t_stat:.3f}, P = {p_val:.4f}")

plt.plot(before, label="Before")
plt.plot(after, label="After")
plt.title("Paired Sample Values")
plt.legend()
plt.show()
# Out:
# Paired T-test: T = -4.911, P = 0.0000

# %%
# 8 . Simulate data and perform both Z-test and T-test, then compare the results using Python.

from scipy.stats import ttest_1samp

sample = np.random.normal(102, 10, 20)
pop_mean = 100
pop_std = 10

# Z-test
z = (np.mean(sample) - pop_mean) / (pop_std / np.sqrt(len(sample)))
p_z = 2 * (1 - norm.cdf(abs(z)))

# T-test
t_stat, p_t = ttest_1samp(sample, pop_mean)

print(f"Z-test: Z = {z:.3f}, P = {p_z:.4f}")
print(f"T-test: T = {t_stat:.3f}, P = {p_t:.4f}")
# Out:
# Z-test: Z = -0.061, P = 0.9512
# T-test: T = -0.048, P = 0.9626

# %%
# 9 . Write a Python function to calculate the confidence interval for a sample mean and explain its significance.

# Generate sample data
sample_data = np.random.normal(loc=100, scale=15, size=30)

# Calculate 95% confidence interval
ci = confidence_interval(sample_data)
print(f"95% Confidence Interval for the mean: {ci}")
# Out:
# 95% Confidence Interval for the mean: (np.float64(94.43486232611247), np.float64(107.01445393718507))

# %%
# 10 . Write a Python program to calculate the margin of error for a given confidence level using sample data.

import numpy as np
from scipy.stats import t

# Function to calculate Margin of Error
def margin_of_error(data, confidence=0.95):
    n = len(data)
    std_err = np.std(data, ddof=1) / np.sqrt(n)
    t_critical = t.ppf((1 + confidence) / 2, df=n - 1)
    moe = t_critical * std_err
    return moe

# Sample data (generate 40 values with mean 50, std dev 10)
sample_data = np.random.normal(loc=50, scale=10, size=40)

# Calculate and print the margin of error
moe = margin_of_error(sample_data, confidence=0.95)
print(f"Margin of Error (95% confidence): {moe:.2f}")
# Out:
# Margin of Error (95% confidence): 3.62

# %%
# 11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.

def bayes_theorem(P_A, P_B_given_A, P_B_given_notA):
    P_notA = 1 - P_A
    P_B = P_B_given_A * P_A + P_B_given_notA * P_notA
    P_A_given_B = (P_B_given_A * P_A) / P_B
    return P_A_given_B

# Example
P_A = 0.01  # prior (e.g., disease)
P_B_given_A = 0.95  # true positive rate
P_B_given_notA = 0.05  # false positive rate

posterior = bayes_theorem(P_A, P_B_given_A, P_B_given_notA)
print(f"Posterior Probability: {posterior:.4f}")
# Out:
# Posterior Probability: 0.1610

# %%
# 12 . Perform a Chi-square test for independence between two categorical variables in Python.

import pandas as pd
from scipy.stats import chi2_contingency

data = pd.DataFrame({
    "Gender": ["Male", "Male", "Female", "Female"],
    "Preference": ["A", "B", "A", "B"],
    "Count": [30, 10, 20, 40]
})

contingency = pd.pivot_table(data, values='Count', index='Gender', columns='Preference', aggfunc=np.sum)
chi2, p, dof, expected = chi2_contingency(contingency)

print(f"Chi-square: {chi2:.3f}, P-value: {p:.4f}")
# Out:
# Chi-square: 15.042, P-value: 0.0001
# <ipython-input-25-1fb0560eedcc>:12: FutureWarning: The provided callable <function sum at 0x7ee650994cc0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   contingency = pd.pivot_table(data, values='Count', index='Gender', columns='Preference', aggfunc=np.sum)

# %%
# 13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data.

# Uses same contingency table as above
print("Expected Frequencies:")
print(expected)
# Out:
# Expected Frequencies:
# [[30. 30.]
#  [20. 20.]]

# %%
#14.Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.

from scipy.stats import chisquare

# Observed frequencies
observed = [40, 35, 25]

# Scale expected frequencies to match the sum of observed
total = sum(observed)
expected = [total / 3] * 3  # Equal distribution, sum = 100

# Perform Chi-square goodness-of-fit test
chi2_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

# Display results
print(f"Chi-Square Statistic = {chi2_stat:.2f}")
print(f"P-value = {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Result: Reject the null hypothesis — observed data does not fit the expected distribution.")
else:
    print("Result: Fail to reject the null hypothesis — observed data fits the expected distribution.")
# Out:
# Chi-Square Statistic = 3.50
# P-value = 0.1738
# Result: Fail to reject the null hypothesis — observed data fits the expected distribution.
